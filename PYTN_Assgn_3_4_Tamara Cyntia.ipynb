# %% [markdown]
# # Libraries

# %%
import numpy as np
import sympy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

mpl.style.use(["ggplot"])
# %matplotlib inline

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# Read the dataset, replace *unknown* with *NaN*, and drop all *NaN* values.

# %%
df = pd.read_csv("bank-additional-full.csv",sep=";")
df = df.replace("unknown",np.nan)
df = df.dropna()
df.head()
# Out:
#    age        job  marital            education default housing loan  \
# 0   56  housemaid  married             basic.4y      no      no   no
# 2   37   services  married          high.school      no     yes   no
# 3   40     admin.  married             basic.6y      no      no   no
# 4   56   services  married          high.school      no      no  yes
# 6   59     admin.  married  professional.course      no      no   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# 2  telephone   may         mon  ...         1    999         0  nonexistent
# 3  telephone   may         mon  ...         1    999         0  nonexistent
# 4  telephone   may         mon  ...         1    999         0  nonexistent
# 6  telephone   may         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          1.1          93.994          -36.4      4.857       5191.0  no
# 2          1.1          93.994          -36.4      4.857       5191.0  no
# 3          1.1          93.994          -36.4      4.857       5191.0  no
# 4          1.1          93.994          -36.4      4.857       5191.0  no
# 6          1.1          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %% [markdown]
# Identify which columns are numerical and categorical.

# %%
pip install dython
# Out:
# Collecting dython
#   Downloading dython-0.7.3-py3-none-any.whl (23 kB)
# Collecting matplotlib>=3.5.3
#   Downloading matplotlib-3.7.1-cp39-cp39-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 8.6 MB/s eta 0:00:00
# Collecting scikit-plot>=0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting seaborn>=0.12.0
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      -------------------------------------- 293.3/293.3 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.4.2 in c:\users\user\anaconda3\lib\site-packages (from dython) (1.4.4)
# Collecting numpy>=1.23.0
#   Downloading numpy-1.24.2-cp39-cp39-win_amd64.whl (14.9 MB)
#      ---------------------------------------- 14.9/14.9 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\user\anaconda3\lib\site-packages (from dython) (1.0.2)
# Collecting psutil>=5.9.1
#   Downloading psutil-5.9.4-cp36-abi3-win_amd64.whl (252 kB)
#      -------------------------------------- 252.5/252.5 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.7.1 in c:\users\user\anaconda3\lib\site-packages (from dython) (1.9.1)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp39-cp39-win_amd64.whl (160 kB)
#      -------------------------------------- 160.2/160.2 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (2.8.2)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.5.3->dython) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.4.2->dython) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->dython) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->dython) (1.2.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.3->dython) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.3->dython) (1.16.0)
# Installing collected packages: psutil, numpy, importlib-resources, contourpy, matplotlib, seaborn, scikit-plot, dython
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.0
#     Uninstalling psutil-5.9.0:
#       Successfully uninstalled psutil-5.9.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.2
#     Uninstalling matplotlib-3.5.2:
#       Successfully uninstalled matplotlib-3.5.2
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# Successfully installed contourpy-1.0.7 dython-0.7.3 importlib-resources-5.12.0 matplotlib-3.7.1 numpy-1.24.2 psutil-5.9.4 scikit-plot-0.3.7 seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.2 which is incompatible.

# %%
from dython.nominal import identify_numeric_columns,identify_nominal_columns

cat_columns,num_columns = identify_nominal_columns(df),identify_numeric_columns(df)
for i,j in zip(["Categorical Columns","Numerical Columns"],[cat_columns,num_columns]):
    print(f"{i}\t: {j}")
# Out:
# Categorical Columns	: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y']
# Numerical Columns	: ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# %% [markdown]
# To find correlation between numerical and categorical variables, we can use the help of *Dython* library.

# %%
from dython.nominal import associations

corr = associations(df)

# %% [markdown]
# Since we only want to see the correlation of features and target, we can slice and take the *y* column.

# %%
df_corr = corr["corr"][["y"]].iloc[:-1].sort_values("y",ascending=False)
df_corr.style.background_gradient(cmap="coolwarm",axis=None)
# Out:
# <style type="text/css">
# #T_1fc4f_row0_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1fc4f_row1_col0 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_1fc4f_row2_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_1fc4f_row3_col0 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_1fc4f_row4_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_1fc4f_row5_col0 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_1fc4f_row6_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_1fc4f_row7_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_1fc4f_row8_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_1fc4f_row9_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1fc4f_row10_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_1fc4f_row11_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_1fc4f_row12_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1fc4f_row13_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_1fc4f_row14_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_1fc4f_row15_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_1fc4f_row16_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_1fc4f_row17_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_1fc4f_row18_col0, #T_1fc4f_row19_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1fc4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fc4f_level0_col0" class="col_heading level0 col0" >y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fc4f_level0_row0" class="row_heading level0 row0" >duration</th>
#       <td id="T_1fc4f_row0_col0" class="data row0 col0" >0.393530</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row1" class="row_heading level0 row1" >nr.employed</th>
#       <td id="T_1fc4f_row1_col0" class="data row1 col0" >0.364230</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row2" class="row_heading level0 row2" >pdays</th>
#       <td id="T_1fc4f_row2_col0" class="data row2 col0" >0.327509</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row3" class="row_heading level0 row3" >poutcome</th>
#       <td id="T_1fc4f_row3_col0" class="data row3 col0" >0.322919</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row4" class="row_heading level0 row4" >euribor3m</th>
#       <td id="T_1fc4f_row4_col0" class="data row4 col0" >0.315869</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row5" class="row_heading level0 row5" >emp.var.rate</th>
#       <td id="T_1fc4f_row5_col0" class="data row5 col0" >0.305365</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row6" class="row_heading level0 row6" >month</th>
#       <td id="T_1fc4f_row6_col0" class="data row6 col0" >0.277624</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row7" class="row_heading level0 row7" >previous</th>
#       <td id="T_1fc4f_row7_col0" class="data row7 col0" >0.228003</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row8" class="row_heading level0 row8" >job</th>
#       <td id="T_1fc4f_row8_col0" class="data row8 col0" >0.153701</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row9" class="row_heading level0 row9" >contact</th>
#       <td id="T_1fc4f_row9_col0" class="data row9 col0" >0.143642</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row10" class="row_heading level0 row10" >cons.price.idx</th>
#       <td id="T_1fc4f_row10_col0" class="data row10 col0" >0.128752</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row11" class="row_heading level0 row11" >campaign</th>
#       <td id="T_1fc4f_row11_col0" class="data row11 col0" >0.069206</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row12" class="row_heading level0 row12" >cons.conf.idx</th>
#       <td id="T_1fc4f_row12_col0" class="data row12 col0" >0.061638</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row13" class="row_heading level0 row13" >education</th>
#       <td id="T_1fc4f_row13_col0" class="data row13 col0" >0.059929</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row14" class="row_heading level0 row14" >age</th>
#       <td id="T_1fc4f_row14_col0" class="data row14 col0" >0.048727</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row15" class="row_heading level0 row15" >marital</th>
#       <td id="T_1fc4f_row15_col0" class="data row15 col0" >0.041455</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row16" class="row_heading level0 row16" >day_of_week</th>
#       <td id="T_1fc4f_row16_col0" class="data row16 col0" >0.026660</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row17" class="row_heading level0 row17" >housing</th>
#       <td id="T_1fc4f_row17_col0" class="data row17 col0" >0.008163</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row18" class="row_heading level0 row18" >loan</th>
#       <td id="T_1fc4f_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1fc4f_level0_row19" class="row_heading level0 row19" >default</th>
#       <td id="T_1fc4f_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# According to [PH717 Module 9 - Correlation and Regression](https://sphweb.bumc.bu.edu/otlt/MPH-Modules/PH717-QuantCore/PH717-Module9-Correlation-Regression/PH717-Module9-Correlation-Regression4.html), the strength of correlatio coefficients can be described as follows:

# %% [markdown]
# | Correlation Coefficient | Decription |
# | :---: | :---: |
# | 1.0 | Perfect Positive |
# | 0.8 to 1.0 | Very Strong |
# | 0.6 to 0.8 | Strong |
# | 0.4 to 0.6 | Moderate |
# | 0.2 to 0.4 | Weak |
# | 0.0 to 0.2 | Very Weak |
# | 0.0 to -0.2 | Very Weak |
# | -0.2 to -0.4 | Weak |
# | -0.4 to -0.6 | Moderate |
# | -0.6 to -0.8 | Strong |
# | -0.8 to -1.0 | Very Strong |
# | -1.0 | Perfect Negative |

# %% [markdown]
# Based on the table above, it can be seen that there are 8 variables that have weak-to-moderate correlation (highlighted in red) and 12 variables that have very weak correlation (highlighted in grey).

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.barplot(data=df_corr,x=df_corr.index,y="y",palette=["pink" if i >= 0.2 else "grey" for i in df_corr["y"]])
plt.title("Correlation of Features and Target")
plt.xticks(rotation=90)
plt.ylabel("")
plt.show()

# %% [markdown]
# Remove the 12 variables that have very weak correlation.

# %%
df = df[list(df_corr[df_corr["y"] >= 0.2].index) + ["y"]]
df.head()
# Out:
#    duration  nr.employed  pdays     poutcome  euribor3m  emp.var.rate month  \
# 0       261       5191.0    999  nonexistent      4.857           1.1   may
# 2       226       5191.0    999  nonexistent      4.857           1.1   may
# 3       151       5191.0    999  nonexistent      4.857           1.1   may
# 4       307       5191.0    999  nonexistent      4.857           1.1   may
# 6       139       5191.0    999  nonexistent      4.857           1.1   may
#
#    previous   y
# 0         0  no
# 2         0  no
# 3         0  no
# 4         0  no
# 6         0  no

# %% [markdown]
# Define independent and dependent variables.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X = df.drop("y",axis=1).copy().apply(le.fit_transform)
y = df["y"].copy()

# %% [markdown]
# Split the dataset into training and testing datasets.

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1221)

print(f"Training dataset\t: {len(X_train)}")
print(f"Testing dataset\t\t: {len(X_test)}")
# Out:
# Training dataset	: 21341
# Testing dataset		: 9147

# %% [markdown]
# Standardize all of the independent variables.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# Create a logistic regression model.

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression(class_weight="balanced",random_state=42,max_iter=5000)
log_model.fit(scaled_X_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=5000, random_state=42)

# %% [markdown]
# Predict using the logistic regression model.

# %%
log_pred = log_model.predict(scaled_X_test)

# %% [markdown]
# Evaluate the logistic regression model.

# %%
from sklearn.metrics import accuracy_score,classification_report,ConfusionMatrixDisplay

plt.figure(dpi=100)
ConfusionMatrixDisplay.from_predictions(y_test,log_pred,ax=plt.gca())
plt.grid(False)
plt.show()

print(f"Accuracy Score: {accuracy_score(y_test,log_pred)*100}%")
# Out:
# Accuracy Score: 83.87449436973871%

# %% [markdown]
# Create the final logistic regression model by fitting the whole dataset.

# %%
final_log_model = LogisticRegression(class_weight="balanced",random_state=42,max_iter=5000)
final_log_model.fit(X,y)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=5000, random_state=42)

# %% [markdown]
# Show the beta coefficients of the logistic regression model.

# %%
pd.DataFrame(
    data=[final_log_model.intercept_[0]] + list(final_log_model.coef_[0]),
    columns=["Unstandardized Coefficients"],
    index=["Constant"] + list(X.columns)
)
# Out:
#               Unstandardized Coefficients
# Constant                         0.386297
# duration                         0.006573
# nr.employed                     -0.273429
# pdays                            0.006973
# poutcome                         1.058322
# euribor3m                       -0.002104
# emp.var.rate                    -0.227553
# month                           -0.119963
# previous                         0.368927

# %% [markdown]
# Write the equation of the logistic regression model where:
# $$ \pi(x) = \frac{e^{\beta_0 + \beta_1X_1 + \beta_2X_2 + ... + \beta_nX_n}}{1 + e^{\beta_0 + \beta_1X_1 + \beta_2X_2 + ... + \beta_nX_n}} $$

# %%
e,x = sp.Symbol("e"),sp.Symbol("(x)")
x_symbols = [sp.Symbol(f"({i})") for i in X.columns]

sums = np.round(final_log_model.intercept_[0],6)
for i in range(len(X.columns)):
    sums += x_symbols[i] * np.round(final_log_model.coef_[0][i],6)

sp.Eq(sp.pi*x,e**sums / (1 + e**sums))
# Out:
# Eq(pi*(x), e**(0.006573*(duration) - 0.227553*(emp.var.rate) - 0.002104*(euribor3m) - 0.119963*(month) - 0.273429*(nr.employed) + 0.006973*(pdays) + 1.058322*(poutcome) + 0.368927*(previous) + 0.386297)/(e**(0.006573*(duration) - 0.227553*(emp.var.rate) - 0.002104*(euribor3m) - 0.119963*(month) - 0.273429*(nr.employed) + 0.006973*(pdays) + 1.058322*(poutcome) + 0.368927*(previous) + 0.386297) + 1))

# %% [markdown]
# # K-Nearest Neighbors

# %% [markdown]
# Find the optimal *K* value by comparing *K* values with their error rates.

# %%
from sklearn.neighbors import KNeighborsClassifier

errors = []
for i in range(1,31):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(scaled_X_train,y_train)
    pred = model.predict(scaled_X_test)
    error = 1 - accuracy_score(y_test,pred)
    errors.append(error)

plt.figure(figsize=(10,4),dpi=200)
plt.plot(range(1,31),errors,color="blue",marker="o",ls="--")
plt.title("Error Rate for Each K Value")
plt.xlabel("K Values")
plt.xticks(range(1,31))
plt.ylabel("Error Rates")
plt.show()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %% [markdown]
# Based on the plot above, it can be seen that the optimal *K* value is 5. Thus, create a KNN model with *K* = 5.

# %%
k = 7
knn_model = KNeighborsClassifier(n_neighbors=k,weights="distance")
knn_model.fit(scaled_X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7, weights='distance')

# %% [markdown]
# Predict using the KNN model.

# %%
knn_pred = knn_model.predict(scaled_X_test)

# %% [markdown]
# Evaluate the KNN model.

# %%
plt.figure(dpi=100)
ConfusionMatrixDisplay.from_predictions(y_test,knn_pred,ax=plt.gca())
plt.grid(False)
plt.show()

print(f"Accuracy Score: {accuracy_score(y_test,knn_pred)*100}%")
# Out:
# Accuracy Score: 89.66874385044277%

# %% [markdown]
# Create the final KNN model by fitting the whole dataset.

# %%
final_knn_model = KNeighborsClassifier(n_neighbors=k,weights="distance")
final_knn_model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=7, weights='distance')

# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# Create a SVM model.

# %%
from sklearn.svm import SVC

svm_model = SVC(class_weight="balanced",random_state=42)
svm_model.fit(scaled_X_train,y_train)
# Out:
# SVC(class_weight='balanced', random_state=42)

# %% [markdown]
# Predict using the SVM model.

# %%
svm_pred = svm_model.predict(scaled_X_test)

# %% [markdown]
# Evaluate the SVM model.

# %%
plt.figure(dpi=100)
ConfusionMatrixDisplay.from_predictions(y_test,svm_pred,ax=plt.gca())
plt.grid(False)
plt.show()

print(f"Accuracy Score: {accuracy_score(y_test,svm_pred)*100}%")
# Out:
# Accuracy Score: 83.12014868262818%

# %% [markdown]
# Create the final SVM model by fitting the whole dataset.

# %%
final_svm_model = SVC(class_weight="balanced",random_state=42)
final_svm_model.fit(X,y)
# Out:
# SVC(class_weight='balanced', random_state=42)

# %% [markdown]
# # Decision Tree

# %% [markdown]
# Create a decision tree model.

# %%
from sklearn.tree import DecisionTreeClassifier

dec_model = DecisionTreeClassifier(max_depth=5,class_weight="balanced",random_state=42)
dec_model.fit(scaled_X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5, random_state=42)

# %% [markdown]
# Predict using the decision tree model.

# %%
dec_pred = dec_model.predict(scaled_X_test)

# %% [markdown]
# Evaluate the decision tree model.

# %%
plt.figure(dpi=100)
ConfusionMatrixDisplay.from_predictions(y_test,dec_pred,ax=plt.gca())
plt.grid(False)
plt.show()

print(f"Accuracy Score: {accuracy_score(y_test,dec_pred)*100}%")
# Out:
# Accuracy Score: 84.12594293210888%

# %% [markdown]
# Show each feature importance based on the decision tree model.

# %%
fig = plt.figure(dpi=200)
pd.DataFrame(
    data=dec_model.feature_importances_,index=X.columns,columns=["Feature Importance"]
).sort_values("Feature Importance",ascending=True).plot(
    figsize=(10,4),
    kind="barh",
    legend=None,
    color="orange",
    ax=plt.gca()
)
plt.xlabel("Feature Importance")
plt.ylabel("Variables")
plt.show()

# %% [markdown]
# Create the final decision tree model by fitting the whole dataset and visualize it.

# %%
from sklearn.tree import plot_tree

final_dec_model = DecisionTreeClassifier(max_depth=5,class_weight="balanced",random_state=42)
final_dec_model.fit(X,y)

plt.figure(figsize=(10,5),dpi=500)
plot_tree(final_dec_model,filled=True,feature_names=X.columns)
plt.show()

# %% [markdown]
# # Random Forest

# %% [markdown]
# Find the optimal number of trees by comparing numbers of trees with their error rates.

# %%
from sklearn.ensemble import RandomForestClassifier

errors = []
for i in range(1,31):
    model = RandomForestClassifier(n_estimators=i,class_weight="balanced",random_state=42)
    model.fit(scaled_X_train,y_train)
    pred = model.predict(scaled_X_test)
    error = 1 - accuracy_score(y_test,pred)
    errors.append(error)

plt.figure(figsize=(10,4),dpi=200)
plt.plot(range(1,31),errors,color="blue",marker="o",ls="--")
plt.title("Error Rate for Each Number of Trees")
plt.xlabel("Numbers of Trees")
plt.xticks(range(1,31))
plt.ylabel("Error Rates")
plt.show()

# %% [markdown]
# Based on the plot above, it can be seen that the optimal number of trees is 5. Thus, create a random forest model with number of trees = 5.

# %%
n = 4
ran_model = RandomForestClassifier(n_estimators=n,class_weight="balanced",random_state=42)
ran_model.fit(scaled_X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=4, random_state=42)

# %% [markdown]
# Predict using the random forest model.

# %%
ran_pred = ran_model.predict(scaled_X_test)

# %% [markdown]
# Evaluate the random forest model.

# %%
plt.figure(dpi=100)
ConfusionMatrixDisplay.from_predictions(y_test,ran_pred,ax=plt.gca())
plt.grid(False)
plt.show()

print(f"Accuracy Score: {accuracy_score(y_test,ran_pred)*100}%")
# Out:
# Accuracy Score: 89.20957691046245%

# %% [markdown]
# Show each feature importance based on the random forest model.

# %%
fig = plt.figure(dpi=200)
pd.DataFrame(
    data=ran_model.feature_importances_,index=X.columns,columns=["Feature Importance"]
).sort_values("Feature Importance",ascending=True).plot(
    figsize=(10,4),
    kind="barh",
    legend=None,
    color="purple",
    ax=plt.gca()
)
plt.xlabel("Feature Importance")
plt.ylabel("Variables")
plt.show()

# %% [markdown]
# Create the final random forest model by fitting the whole dataset.

# %%
final_ran_model = RandomForestClassifier(n_estimators=n,class_weight="balanced",random_state=42)
final_ran_model.fit(X,y)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=4, random_state=42)

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# Create a naive bayes model.

# %%
from sklearn.naive_bayes import BernoulliNB

naive_model = BernoulliNB()
naive_model.fit(scaled_X_train,y_train)
# Out:
# BernoulliNB()

# %% [markdown]
# Predict using the naive bayes model.

# %%
naive_pred = naive_model.predict(scaled_X_test)

# %% [markdown]
# Evaluate the naive bayes model.

# %%
plt.figure(dpi=100)
ConfusionMatrixDisplay.from_predictions(y_test,naive_pred,ax=plt.gca())
plt.grid(False)
plt.show()

print(f"Accuracy Score: {accuracy_score(y_test,naive_pred)*100}%")
# Out:
# Accuracy Score: 80.82431398272658%

# %% [markdown]
# Create the final naive bayes model by fitting the whole dataset.

# %%
final_naive_model = BernoulliNB()
final_naive_model.fit(X,y)
# Out:
# BernoulliNB()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Even though the KNN and random forest models have higher accuracy scores than the other models, it can be seen that they only predicted a small portion of the *yes* label right. In other words, those 2 models are inaccurate and thus can't be used. For the remaining models, the decision tree model has the highest accuracy score, which is 84.1259%. So, it can be concluded that the decision tree model is the best model for this case.

# %%
preds = [log_pred,svm_pred,dec_pred,naive_pred]
models = ["Logistic Regression","Support Vector Machine","Decision Tree","Naive Bayes"]
accuracy_scores = [accuracy_score(y_test,i)*100 for i in preds]

comparison = pd.DataFrame(
    data=accuracy_scores,columns=["Accuracy Scores"],index=models
).sort_values("Accuracy Scores",ascending=False)

plt.figure(figsize=(10,4),dpi=200)
barplot = sns.barplot(
    data=comparison,
    x="Accuracy Scores",
    y=comparison.index,
    orient="h",
    palette=["green" if i == comparison.head(1).iloc[0,0] else "red" for i in comparison["Accuracy Scores"]]
)
for bars in barplot.containers:
    barplot.bar_label(bars,padding=5)
plt.title("Accucary Score for Each Model")
plt.xlabel("Accuracy Scores (%)")
plt.ylabel("Models")
plt.xlim(xmax=100)
plt.show()

# %% [markdown]
# Compare the actual value to each model's prediction.

# %%
pd.DataFrame(data=np.stack(preds,axis=1),columns=models,index=y_test.values).rename_axis(index="Actual Values")
# Out:
#               Logistic Regression Support Vector Machine Decision Tree  \
# Actual Values
# no                             no                     no            no
# no                             no                     no            no
# no                             no                     no            no
# no                             no                     no            no
# no                             no                    yes           yes
# ...                           ...                    ...           ...
# no                             no                     no            no
# no                            yes                    yes            no
# no                             no                     no            no
# yes                           yes                    yes           yes
# no                             no                     no            no
#
#               Naive Bayes
# Actual Values
# no                     no
# no                     no
# no                     no
# no                     no
# no                     no
# ...                   ...
# no                     no
# no                    yes
# no                     no
# yes                   yes
# no                     no
#
# [9147 rows x 4 columns]

# %% [markdown]
# Save all the final models for future use.

# %%
from joblib import dump

final_models = [final_log_model,final_knn_model,final_svm_model,
                final_dec_model,final_ran_model,final_naive_model]
file_names = ["logistic_regression","knn","svm","decision_tree","random_forest","naive_bayes"]

for i,j in zip(final_models,file_names):
    dump(i,j + ".joblib")
    print(f"{j}.joblib has been saved successfully!")
# Out:
# logistic_regression.joblib has been saved successfully!
# knn.joblib has been saved successfully!
# svm.joblib has been saved successfully!
# decision_tree.joblib has been saved successfully!
# random_forest.joblib has been saved successfully!
# naive_bayes.joblib has been saved successfully!
